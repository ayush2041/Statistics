# %%
import numpy as np 
from scipy.stats import norm

# %%
sample = [172, 174, 168, 169, 171, 173, 175, 170, 169, 172]
population_mean = 170
population_std = 3
samp_mean = np.mean(sample)
n = len(sample)

# %%
z_score = (samp_mean - population_mean) / (population_std / np.sqrt(n)) #Formula for Z-Test
z_score
# Out:
# np.float64(1.3703203194063098)

# %%
p_value = 2 * (1 - norm.cdf(abs(z_score)))  #cdf-> Cumulative Distribution Function , abs-> Absolute value
p_value
# Out:
# np.float64(0.17058693287143756)

# %%
alpha = 0.05

if p_value < alpha:
    print("I will reject the null hypothesis")
else:
    print("I will accept the null hypothesis")
# Out:
# I will accept the null hypothesis
